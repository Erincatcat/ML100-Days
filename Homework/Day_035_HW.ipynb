# %% [markdown]
# # 練習時間
# 相信大家對回歸問題及分類問題都有初步的了解。今天的作業希望大家搜尋有關 multi-label 的案例問題。下圖是電影 "奇異博士" 的分類。可以看到同時有 "Action", "Adventure", "Fantasy" 的類別存在，代表這是個多標籤的問題。

# %% [markdown]
# ![image](https://cdn-images-1.medium.com/max/1000/1*r0gYXMSQf5VhdMyl2bRDyg.png)

# %% [markdown]
# 請搜尋目標為多標籤問題 (Multi-label) 的機器學習案例，了解其資料來源、目標以及評估指標為何
# Hint: 服飾

# %% [markdown]
# 以switch為例，在amazon上，標籤有三種：
# * Video Games
# * Video Games > Nintendo Switch > Consoles
# * Electronics > Video Game Consoles & Accessories

# %%
from IPython.display import Image
Image(filename = './Data/merchandise.png', width=500)

# %%
Image(filename = './Data/information.png', width=1000)

# %% [markdown]
# 課後補充:
#
# [回歸與分類的比較](http://zylix666.blogspot.com/2016/06/supervised-classificationregression.html)
